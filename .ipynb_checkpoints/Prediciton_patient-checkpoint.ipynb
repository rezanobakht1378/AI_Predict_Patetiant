# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_xlsx('patient.xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_xlsx('patient.xlsx')
#       2 df.head()
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'
